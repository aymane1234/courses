# %%
import seaborn as sns 
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
sns.load_dataset('tips')
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df = sns.load_dataset('tips')

# %%
sns.relplot(x = 'tip', y = 'total_bill', data = df)

# %%
sns.relplot(x = 'tip', y = 'total_bill', data = df, hue = 'smoker')

# %%
sns.relplot(x = 'tip', y = 'total_bill', data = df, hue = 'day')

# %%
sns.relplot(x = 'tip', y = 'total_bill', data = df, hue = 'day',style='smoker')

# %%
sns.relplot(x = 'tip', y = 'total_bill', data = df,size= 'tip')

# %%
d1 = pd.DataFrame(np.random.rand(300,2), columns=['a','b'])

# %%
d1
# Out:
#             a         b
# 0    0.109213  0.120858
# 1    0.360780  0.658038
# 2    0.017787  0.938979
# 3    0.723444  0.455255
# 4    0.212476  0.871644
# ..        ...       ...
# 295  0.480345  0.430784
# 296  0.076355  0.036995
# 297  0.407751  0.043121
# 298  0.251023  0.014496
# 299  0.701736  0.306031
#
# [300 rows x 2 columns]

# %%
sns.relplot(x = 'a',y = 'b', kind='line',data=d1,sort = True)

# %%
iris = sns.load_dataset('iris')

# %%
sns.catplot(x  ='day' ,y = 'tip',data=df)

# %%
sns.catplot(x  ='smoker' ,y = 'tip',data=df)

# %%
sns.catplot(x  ='day' ,y = 'tip',kind= 'box',data=df)

# %%
sns.catplot(x  ='day' ,y = 'tip',kind= 'box',data=df,hue = 'sex')

# %%
X = np.random.randn(1000000)

# %%
X
# Out:
# array([ 0.14686691, -1.93566301, -0.32567873, ..., -0.15173178,
#         1.79404369, -0.71974438])

# %%
sns.displot(X)

# %%
sns.jointplot(x = df['total_bill'],y = df['tip'])

# %%
sns.pairplot(iris)

# %%
sns.lmplot(x = 'total_bill',y = 'tip', data=df)

# %%
sns.regplot(x = 'total_bill',y = 'tip', data=df)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.lmplot(x = 'total_bill',y = 'tip', data=df)

# %%
sns.lmplot(x = 'total_bill',y = 'tip', data=df,col='day')
